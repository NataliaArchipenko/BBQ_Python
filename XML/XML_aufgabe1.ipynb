# %% [markdown]
# **XML Aufgabe 1**
# Auf Wohlgeformheit und Gülgkeit untersuchen

# %%
<?xml version="1.0" encoding="UTF-8"?>   # Beginn ist richtig
<!DOCTYPE Bibliothek [ 
  <!ELEMENT Bibliothek (Buch+)>
  <!ELEMENT Buch (Titel, Autor, Erscheinungsjahr, Verlag, ISBN, Zusatzinfo*
  <!ELEMENT Titel (#PCDATA)>
  <!ELEMENT Autor (#PCDATA)>
  <!ELEMENT Erscheinungsjahr (#PCDATA)>
  <!ELEMENT Verlag (#PCDATA)>
  <!ATTLIST Verlag
            ort CDATA #REQUIRED>
  <!ELEMENT ISBN (#PCDATA)>
  <!ELEMENT Zusatzinfo (Seitenzahl?, Untertitel+)>
  <!ATTLIST Zusatzinfo
            typ (Technisch | Roman | Wissenschaftlich) "Technisch">
  <!ELEMENT Seitenzahl (#PCDATA)>
  <!ELEMENT Untertitel (#PCDATA)>
]>
<Bibliothek>
  <Buch>
    <Titel>Grundlagen XML</Titel>
    <Autor>Max Mustermann</Autor>
    <Erscheinungsjahr>2023</Erscheinungsjahr>
    <Verlag>Open Books</Verlag> <!-- Fehler: Pflichtattribut Ort fehlt -->
    <ISBN>978-1234567890</ISBN>
    <Zusatzinfo typ="Technisch">
      <Seitenzahl>300</Seitenzahl>
      <Untertitel>Ein Handbuch</Untertitel>
    </Zusatzinfo>
  </Buch>
  <Buch>
    <Titel>Fehlerhafte Attributwerte</Titel>
    <Autor>Lisa Beispiel</Autor>
    <Erscheinungsjahr>2021</Erscheinungsjahr>
    <Verlag ort="Berlin">Verlag XY</Verlag> <!-- Fehler: Nach Verlag  fehlt  ISBN-->
    <Zusatzinfo typ="Fiktion"><!-- Fehler:  Wert für typ ist ungültig, da er nicht innerhalb erhaltene type für Zusatzinfo liegt "Fiktion" ist falsch-->
      <Untertitel>Die Praxis</Untertitel>
    </Zusatzinfo>
  </Buch>
  <Buch>
    <Autor>Anna XML</Autor> <!-- Fehler: Felt title-->
    <Erscheinungsjahr>2020</Erscheinungsjahr>
    <Verlag ort="Hamburg">Tech Verlag</Verlag>
    <ISBN>978-1234432110</ISBN>
    <Zusatzinfo> <!-- Fehler: Felt Untertitle und type-->
      <Seitenzahl>400</Seitenzahl>
    </Zusatzinfo>
  </Buch>
  <Buch>
    <Titel>Wohlgeformtheit Fehler</Titel>
    <Autor>Max Mustermann</Autor>
    <Erscheinungsjahr>2019</Erscheinungsjahr>
    <Verlag>Test Verlag</Verlag>
    <ISBN>978-9876543210</ISBN>
    <Zusatzinfo>
      <Untertitel>Zusammenfassung</Untertitel>
    </Zusatzinfo>
  </Buch>
  <Buch>
    <Titel>Ungültiger Seitenzahl-Inhalt</Titel>
    <Autor>Autor Max</Autor>
    <Erscheinungsjahr>2024</Erscheinungsjahr>
    <Verlag ort="München">XML Verlag</Verlag>
    <ISBN>978-6543210987</ISBN>
    <Zusatzinfo> <!-- Fehler: Felt  type oder ist es eine Standard???-->
      <Seitenzahl>zwei hundert</Seitenzahl> 
      <Untertitel>Techniken</Untertitel>
    </Zusatzinfo>
  </Buch>
  <Buch>
    <Titel>Zu viele Untertitel</Titel>
    <Autor>Max Mustermann</Autor>
    <Erscheinungsjahr>2023</Erscheinungsjahr>
    <Verlag ort="Open Books">Open Books</Verlag> <!-- Fehler: ISBN nach Verlag fehlt-->
    <Zusatzinfo typ="Technisch">
      <Untertitel>Kapitel 1</Untertitel>
      <Untertitel>Kapitel 2</Untertitel>
      <Untertitel>Kapitel 3</Untertitel>
    </Zusatzinfo>
  </Buch>
  <Buch>
    <Titel>Fehlerhafte Struktur</Titel>
    <Autor>Beispiel Autor</Autor>
    <Erscheinungsjahr>2025</Erscheinungsjahr>
    <Verlag ort="Köln">Pro Verlag</Verlag>
    <ISBN>978-0987654321</ISBN>
  </Buch>

<Buch>
    <Titel>Doppelter Verlag</Titel>
    <Autor>Autor Beispiel</Autor>
    <Erscheinungsjahr>2026</Erscheinungsjahr>
    <Verlag ort="Leipzig">Alpha Verlag</Verlag><!-- Fehler: Doppeltes Ort darf micht sein, da steht einfach verlah, ohne zusätliche Simbole->
    <Verlag ort="Berlin">Beta Verlag</Verlag>
    <ISBN>978-1122334455</ISBN>
    <Zusatzinfo>
      <Untertitel>Mehr Verlage</Untertitel>
    </Zusatzinfo>
  </Buch>

 <Buch>
    <Titel>Kein Autor</Titel> <!-- Fehler: Author fehlt->
    <Erscheinungsjahr>2027</Erscheinungsjahr>
    <Verlag ort="Hamburg">Tech Verlag</Verlag>
    <ISBN>978-9988776655</ISBN>
    <Zusatzinfo>
      <Untertitel>Fehlender Autor</Untertitel>
    </Zusatzinfo>
  </Buch>
  <Buch>
    <Titel>Mehrere Zusatzinfos</Titel>
    <Autor>Max Mustermann</Autor>
    <Erscheinungsjahr>2028</Erscheinungsjahr>
    <Verlag ort="Berlin">Multiple Infos Verlag</Verlag>
    <ISBN>978-5544332211</ISBN>
    <Zusatzinfo typ="Wissenschaftlich">
      <Seitenzahl>200</Seitenzahl>
      <Untertitel>Analyse</Untertitel>
    </Zusatzinfo>
    <Zusatzinfo typ="Technisch">
      <Seitenzahl>150</Seitenzahl>
      <Untertitel>Praxis</Untertitel>
    </Zusatzinfo>
  </Buch></Bibliothek>

# %% [markdown]
# **XML Aufgabe 2**
#
# Auf Wohlgeformheit und Gülgkeit untersuchen
# Die DTD ist diesmal in einer eigenen Datei  schule.dtd  gespeichert.

# %%
<!ELEMENT Schule (Klassen)>
<!ELEMENT Klassen (Klasse+)>

<!ELEMENT Klasse (Name, Raum, Jahrgang, Stundenplan?)>
<!ATTLIST Klasse ID ID #REQUIRED>
<!ELEMENT Name (#PCDATA)>
<!ELEMENT Raum (#PCDATA)>
<!ELEMENT Jahrgang (#PCDATA)>
<!ELEMENT Stundenplan (Stunde*)>
<!ELEMENT Stunde (Fach, Lehrer)>
<!ELEMENT Fach (#PCDATA+)>
<!ATTLIST Fach Fachrichtung (Mathematik | Deutsch | Englisch | Naturwissens
<!ELEMENT Lehrer (#PCDATA)>
<?xml version="1.0" encoding="UTF-8"?>
<!DOCTYPE Schule SYSTEM "schule.dtd">
<Schule>
    <Klassen>
        <Klasse ID="K01">
            <Name>10 A<Buch></Name>   <!--Fehler Buch darf hier nicht sein-->        
                <Raum>101</Raum>
            <Jahrgang>10</Jahrgang>
            <Stundenplan>
                <Stunde>
                    <Fach Fachrichtung="Mathematik">Mathematik</Fach>
                    <Lehrer>Herr Müller</Lehrer>
                </Stunde>
            </Stundenplan>
        </Klasse>
        <Klasse ID="K02">
            <Name>11B & 11C</Name>  <!--Fehler:  ist in (#PCDATA)--> 
            <Raum>102</Raum>
            <Jahrgang>11</Jahrgang>
            <Stundenplan>
                <Stunde>
                    <Fach Fachrichtung="Englisch">Englisch</Fach>
                    <Lehrer>Frau Schmidt</Lehrer>
                </Stunde>
            </Stundenplan>
        </Klasse>
        <Klasse ID="K04">
            <Name>12A</Name>
            <Raum>104</Raum>
            <Jahrgang>12</Jahrgang>
        </Klasse>
        <Klasse ID="K05">
            <Name>13B</Name>
            <Raum>105</Raum>
            <Jahrgang>13</Jahrgang>
            <Stundenplan></Stundenplan>
        </Klasse>
        <Klassen>
            <Klasse ID="K06">
                <Name>14A</Name>
                <Raum>106</Raum>
                <Jahrgang>14</Jahrgang>
            </Klasse>
        <Klasse ID="K07">
            <Name>10C</Name>
            <Raum>107</Raum>
            <Jahrgang>10</Jahrgang>
            <Stundenplan>
                <Stunde>
                    <Fach>Mathematik</Fach>
                    <Lehrer>Herr Schwarz</Lehrer>
                </Stunde>
            </Stundenplan>
        </Klasse>
        <Klasse>
            <Name>11D</Name>
            <Raum>108</Raum>
            <Jahrgang>11</Jahrgang>
            <Stundenplan><Stunde></Stunde></Stundenplan>
        </Klasse>
        <Klasse ID="K08">
            <Name>12C</Name>
            <Raum>109</Raum>
            <Jahrgang>12</Jahrgang>
            <Stundenplan>
                <Stunde>
                    <Fach></Fach>                     <Lehrer>Frau Weiss</Lehrer>
                </Stunde>
            </Stundenplan>
</Klasse>
        <Klasse ID="K09">
            <Name>13A</Name>
            <Raum>110</Raum>
            <Jahrgang>13</Jahrgang>
            <Stundenplan>
                <Stunde>
                    <Fach Fachrichtung="Kunst">Kunst</Fach>
                    <Lehrer>Herr Braun</Lehrer>
                </Stunde>
            </Stundenplan>
        </Klasse>
        <Klasse ID="K10">
            <Name>9B</Name>
            <Raum>111</Raum>
            <Jahrgang>9</Jahrgang>
            <Stundenplan>
                <Stunde>
                    <Fach Fachrichtung="Mathematik">Englisch</Fach>                     <Lehrer>Herr Müller</Lehrer>
                </Stunde>
            </Stundenplan>
        </Klasse>
    </Klassen>
    <Klassen>
        <Klasse ID="K03">
            <Name>9<A</Name>
            <Raum>103</Raum>
            <Jahrgang>9</Jahrgang>
        </Klasse>
    </Klassen>
    <!--Fehler!:  Fehlt Schule am Ende-->
