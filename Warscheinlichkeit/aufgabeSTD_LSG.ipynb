# %%
# !pip install openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\AndreasWagner\OneDrive - BBQ - Baumann Bildung und Qualifizierung GmbH\BBQ Berlin\material\__unterricht\ds stack\aufgabe std\data.xlsx", usecols="B")
df.head()
# Out:
#   Standardnormalverteilung
# 0                      NaN
# 1              Hintergrund
# 2                Aufgabe 1
# 3                Aufgabe 2
# 4                Aufgabe 3

# %%
df.tail()
# Out:
#    Standardnormalverteilung
# 84               842.866667
# 85               849.616667
# 86                    874.7
# 87               878.783333
# 88                   897.45

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 1 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Standardnormalverteilung  85 non-null     object
# dtypes: object(1)
# memory usage: 844.0+ bytes

# %%
df = df.replace(",",".")

# %%
df = df.iloc[9:]

# %%
df = df.astype(float)

# %%
""df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 9 to 88
# Data columns (total 1 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Standardnormalverteilung  80 non-null     object
# dtypes: object(1)
# memory usage: 772.0+ bytes

# %%
df = df.rename({"Standardnormalverteilung":"Sample Data"}, axis=1)

# %%
df_norm = (df - df.mean())/df.std()

# %%
df_norm
# Out:
#     Sample Data
# 9     -2.374169
# 10    -2.306559
# 11    -2.306559
# 12    -2.081191
# 13    -1.746519
# ..          ...
# 84     1.350040
# 85     1.441314
# 86     1.780493
# 87     1.835708
# 88     2.088121
#
# [80 rows x 1 columns]

# %%
import seaborn as sns
sns.histplot(df, kde=True);

# %%
sns.histplot(df_norm, kde=True);

# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import norm

x = np.linspace(-4, 4, 50)

y = norm.pdf(x, loc=0, scale=1)

sns.kdeplot(df_norm, label="Sample Data")
plt.plot(x, y, ls="--", c="r", label="STD Normalverteilung")
plt.legend();
