# %% [markdown]
# # Pandas Data Visualization Übung - Aufgabe
# Das ist eine kleine Übung zur Anwendung der eingebauten Visualisierungsmöglichkeiten in *Pandas*. Dazu nutzen wir das **df3** CSV. Bitte stellt die folgenden Diagramme durch nutzung von Pandas dar. Die Imports seien gegeben:

# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('df3')
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# **Erstelle dieses Scatter Plot von b vs. a. Achte auf die Farbe und Größe der Punkte. Versuche außerdem es in die vorgegebene Form zu bringen. Dazu könnte eine Auffrischung der Matplotlib-Befehle helfen.**

# %%
fig = plt.figure(figsize=(10, 2))

plt.scatter(df3['a'], df3['b'], color='red', marker='o')


#plt.title('Scatter-Plot')
#plt.xlabel('a-Achse')
#plt.ylabel('b-Achse')
plt.xticks([])
plt.yticks([])
plt.gca().spines['top'].set_visible(False) # nimmt schwarze Komtur ab für jeder Seite
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.grid(False)
plt.grid(False)
plt.show()

# %% [markdown]
# **Erstelle ein Histogramm der "a" Spalte.**

# %%
# Plot hier
fig = plt.figure(figsize=(4.5, 3))
plt.hist(df3['a'])
plt.xticks([])
plt.yticks([])
plt.gca().spines['top'].set_visible(False) # nimmt schwarze Komtur ab für jeder Seite
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.grid(False)
plt.grid(False)
plt.show()

# %% [markdown]
# **Diese Plots sind soweit okay. Sie sehen aber nicht einheitlich aus. Nutze das `ggplot` Stylesheet, um das Erscheinungsbild der folgenden Diagramme zu beeinflussen. Erstelle dann das Histogramm von eben erneut und füge zusätzlich mehr Teilbalken hinzu.**

# %%
# Style hier
plt.style.use('ggplot')

# %%
# Plot hier
fig = plt.figure(figsize=(4, 3))
plt.hist(df3['a'], bins = 25, alpha = 0.5)
#plt.title('Scatter-Plot')
#plt.xlabel('a-Achse')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# **Erstelle ein Box Plot, dass die Spalten a und b vergleicht.**

# %%
df3[['a', 'b']].plot(kind="box")
# Out:
# <Axes: >

# %%
# Plot hier
fig, ax = plt.subplots()
ax.boxplot(df3[['a','b']])
#plt.boxplot(df3[['a','b']], patch_artist=True)
ax.boxplot(df3[['a','b']], boxprops=dict(color='red'))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c97532cef0>,
#   <matplotlib.lines.Line2D at 0x2c97532ccb0>,
#   <matplotlib.lines.Line2D at 0x2c97504bf20>,
#   <matplotlib.lines.Line2D at 0x2c97504b560>],
#  'caps': [<matplotlib.lines.Line2D at 0x2c97532c290>,
#   <matplotlib.lines.Line2D at 0x2c97532ca40>,
#   <matplotlib.lines.Line2D at 0x2c97504b590>,
#   <matplotlib.lines.Line2D at 0x2c97504b7a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2c97532e300>,
#   <matplotlib.lines.Line2D at 0x2c97504bc50>],
#  'medians': [<matplotlib.lines.Line2D at 0x2c974f242f0>,
#   <matplotlib.lines.Line2D at 0x2c97504b110>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2c97504ae10>,
#   <matplotlib.lines.Line2D at 0x2c97504a3f0>],
#  'means': []}

# %% [markdown]
# **Erstelle ein KDE Plot der Spalte "d".**

# %%
# Plot hier
import numpy as np 
fig = plt.figure(figsize=(4, 3))
import seaborn as sns
sns.kdeplot(df3['d'])
plt.xlim(-0.5, 1.5)
plt.xticks(np.arange(-0.5, 1.75, 0.25))
# Out:
# ([<matplotlib.axis.XTick at 0x2c9750d87d0>,
#   <matplotlib.axis.XTick at 0x2c9750d9a60>,
#   <matplotlib.axis.XTick at 0x2c9750495b0>,
#   <matplotlib.axis.XTick at 0x2c9750d9d30>,
#   <matplotlib.axis.XTick at 0x2c975139730>,
#   <matplotlib.axis.XTick at 0x2c9751381a0>,
#   <matplotlib.axis.XTick at 0x2c975164050>,
#   <matplotlib.axis.XTick at 0x2c975138fe0>,
#   <matplotlib.axis.XTick at 0x2c975167d70>],
#  [Text(-0.5, 0, '−0.50'),
#   Text(-0.25, 0, '−0.25'),
#   Text(0.0, 0, '0.00'),
#   Text(0.25, 0, '0.25'),
#   Text(0.5, 0, '0.50'),
#   Text(0.75, 0, '0.75'),
#   Text(1.0, 0, '1.00'),
#   Text(1.25, 0, '1.25'),
#   Text(1.5, 0, '1.50')])

# %% [markdown]
# **Finde heraus, wie wir die Linienbreite erhöhen und die Linie stricheln können.**
#
# *Hinweis: Normalerweise würden wir ein KDE Diagramm nicht stricheln.*

# %%
# Plot hier
fig = plt.figure(figsize=(4, 3))
sns.kdeplot(df3['d'], color='red', linewidth=3, linestyle='--')
plt.xlim(-0.5, 1.5)
plt.xticks(np.arange(-0.5, 1.75, 0.25))
# Out:
# ([<matplotlib.axis.XTick at 0x2c974ce6480>,
#   <matplotlib.axis.XTick at 0x2c974ce6510>,
#   <matplotlib.axis.XTick at 0x2c97fcbff50>,
#   <matplotlib.axis.XTick at 0x2c975012060>,
#   <matplotlib.axis.XTick at 0x2c974cb2bd0>,
#   <matplotlib.axis.XTick at 0x2c974cb2930>,
#   <matplotlib.axis.XTick at 0x2c974fafd40>,
#   <matplotlib.axis.XTick at 0x2c974cb33e0>,
#   <matplotlib.axis.XTick at 0x2c974cb3710>],
#  [Text(-0.5, 0, '−0.50'),
#   Text(-0.25, 0, '−0.25'),
#   Text(0.0, 0, '0.00'),
#   Text(0.25, 0, '0.25'),
#   Text(0.5, 0, '0.50'),
#   Text(0.75, 0, '0.75'),
#   Text(1.0, 0, '1.00'),
#   Text(1.25, 0, '1.25'),
#   Text(1.5, 0, '1.50')])

# %% [markdown]
# **Erstelle ein Flächendiagramm (en. area plot) für alle Spalten. Nutze dabei aber nur die ersten 30 Zeilen.**
#
# *Hinweis: Für die Zeilen kannst du .iloc nutzen.*

# %%
# Plot hier

data= df3.iloc[:30].plot.area(alpha = 0.5)

# %% [markdown]
# ## Bonus Aufgabe!
# Das könnte wirklich schwer sein, weshalb es okay ist, sich auf die Lösung zu beziehen, wenn man nicht weiter kommt.
#
# **Sicher fällt euch auf, dass die Legende in der vorherigen Lösung das eigentliche Diagramm überdeckt. Findest du einen Weg, um die Legende neben dem eigentlichen Diagramm anzuzeigen?**
#
# *Hinweis: Google Suche nach einem guten Stackoverflow-Link zu diesem Thema hilft.*

# %%
# Plot hier
fig, ax = plt.subplots()
data= df3.iloc[:30].plot.area(alpha = 0.5, ax= ax)
sns.move_legend(ax, "center right")# legend verschieben

# %% [markdown]
# # Gut gemacht!
